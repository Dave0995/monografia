# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("white")
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Carga del dataset
#
# Utilizando spark se realizo una partición del 2.5% de los datos del dataset original.

# %%
with open("header.txt", "r") as f:
    line = f.readline()
    cols = line.split(",")
    
df = pd.read_csv("data_sample.csv", header = None, sep = ",", names = cols)
df.head()
# Out:
#    periodo   id_cli  fecha_nacimiento     edad genero estado_civil  \
# 0   202003  2089776          19840630 35.63860      M   DIVORCIADO
# 1   201902  2088089          19860727 32.47639      M  UNION LIBRE
# 2   202001  3892351          19910108 28.93634      M      SOLTERO
# 3   202008  2897552          19900903 29.88364      M      SOLTERO
# 4   202001  4782141          19790623 40.48186      F   NO INFORMA
#
#    nivel_academico            profesion      ocupacion tipo_vivienda  \
# 0        TECNOLOGO  TECNOLOGIA SISTEMAS       Empleado     ALQUILADA
# 1       NO INFORMA                   \N  Independiente      FAMILIAR
# 2        TECNOLOGO                OTROS  Independiente            \N
# 3        BACHILLER                   \N       Empleado            \N
# 4  SIN INFORMACION                   \N       Empleado            \N
#
#    ult_actual  categoria  codigo_ciiu ind_mora_vigente cartera_castigada  \
# 0    20180526    1.00000           10                N                 N
# 1    20181120    4.00000         8230                N                 N
# 2    20190802    4.00000           10                N                 N
# 3    20190906    1.00000           10                N                 N
# 4    20191211    1.00000           10                N                 N
#
#   ciudad_residencia departamento_residencia ciudad_laboral  \
# 0              CALI                   VALLE           CALI
# 1           PALMIRA                   VALLE             \N
# 2          MEDELLIN               ANTIOQUIA             \N
# 3          MEDELLIN               ANTIOQUIA       MEDELLIN
# 4       BOGOTA D.C.            CUNDINAMARCA             \N
#
#   departamento_laboral rechazo_credito  mora_max  cant_moras_30_ult_12_meses  \
# 0                VALLE              \N       NaN                         NaN
# 1                   \N              \N       NaN                         NaN
# 2                   \N              \N   0.00000                     0.00000
# 3            ANTIOQUIA              \N   1.00000                     0.00000
# 4                   \N              \N   0.00000                     0.00000
#
#    cant_moras_60_ult_12_meses  cant_moras_90_ult_12_meses  cupo_total_tc  \
# 0                         NaN                         NaN        0.00000
# 1                         NaN                         NaN        0.00000
# 2                     0.00000                     0.00000        0.00000
# 3                     0.00000                     0.00000        0.00000
# 4                     0.00000                     0.00000        0.00000
#
#   tenencia_tc  cuota_tc_bancolombia tiene_consumo tiene_crediagil  \
# 0          NO               0.00000            \N              \N
# 1          NO               0.00000            \N              \N
# 2          SI               0.00000            \N              \N
# 3          NO               0.00000            \N              \N
# 4          NO               0.00000             X              \N
#
#    nro_tot_cuentas  ctas_activas tiene_ctas_activas  ctas_embargadas  \
# 0          1.00000       1.00000                  X          0.00000
# 1          1.00000       1.00000                  X          0.00000
# 2          1.00000       1.00000                  X          0.00000
# 3          1.00000       1.00000                  X          0.00000
# 4          1.00000       1.00000                  X          0.00000
#
#   tiene_ctas_embargadas pension_fopep  cuota_cred_hipot tiene_cred_hipo_1  \
# 0                    \N            \N               NaN                \N
# 1                    \N            \N               NaN                \N
# 2                    \N            \N               NaN                \N
# 3                    \N            \N               NaN                \N
# 4                    \N            \N               NaN                \N
#
#   tiene_cred_hipo_2  mediana_nom3  mediana_pen3  ingreso_nompen cat_ingreso  \
# 0                \N 1255032.00000       0.00000   1255032.00000         NOM
# 1                \N       0.00000       0.00000         0.00000          \N
# 2                \N       0.00000       0.00000         0.00000          \N
# 3                \N       0.00000       0.00000         0.00000          \N
# 4                \N 4353538.00000       0.00000   4353538.00000         NOM
#
#    ingreso_final  cant_mora_30_tdc_ult_3m_sf  cant_mora_30_consum_ult_3m_sf  \
# 0  1391032.00000                     0.00000                        0.00000
# 1  2327500.00000                         NaN                            NaN
# 2  6519750.00000                         NaN                            NaN
# 3  1484205.00000                     0.00000                        0.00000
# 4  4353334.00000                     0.00000                        0.00000
#
#    cuota_de_vivienda  cuota_de_consumo  cuota_rotativos  \
# 0            0.00000           0.00000          0.00000
# 1            0.00000           0.00000          0.00000
# 2            0.00000           0.00000          0.00000
# 3            0.00000           0.00000          0.00000
# 4            0.00000      386578.00000      11000.00000
#
#    cuota_tarjeta_de_credito  cuota_de_sector_solidario  \
# 0                   0.00000                    0.00000
# 1                   0.00000                    0.00000
# 2                   0.00000                    0.00000
# 3                   0.00000                    0.00000
# 4             1006000.00000                    0.00000
#
#    cuota_sector_real_comercio    cupo_tc_mdo  saldo_prom3_tdc_mdo  \
# 0                     0.00000        0.00000              0.00000
# 1                     0.00000        0.00000              0.00000
# 2                     0.00000        0.00000              0.00000
# 3                524000.00000        0.00000              0.00000
# 4                 28000.00000 25800000.00000       16242500.00000
#
#    cuota_tc_mdo  saldo_no_rot_mdo  cuota_libranza_sf  cant_oblig_tot_sf  \
# 0       0.00000           0.00000            0.00000            0.00000
# 1       0.00000           0.00000            0.00000                NaN
# 2       0.00000           0.00000            0.00000                NaN
# 3       0.00000     2555000.00000            0.00000            0.00000
# 4  751000.00000      211000.00000            0.00000            4.00000
#
#    cant_cast_ult_12m_sr           ind rep_calif_cred  pol_centr_ext  \
# 0               0.00000  695516.00000              C        0.00000
# 1                   NaN 1187025.00000       SIN INFO            NaN
# 2                   NaN 3879251.25000       SIN INFO            NaN
# 3               1.00000  210681.47500              F        7.00000
# 4               0.00000 1615755.80000              C        0.00000
#
#   convenio_lib  ingreso_nomina  ingreso_segurida_social  gasto_familiar
# 0           \N   1255032.00000                      NaN    304687.00000
# 1           \N             NaN                      NaN    187990.00000
# 2           \N             NaN                      NaN    862348.92000
# 3           \N             NaN            1484205.00000   1056864.00000
# 4        70831   4353538.00000            3500000.00000    248386.00000

# %% [markdown]
# ## Analisis exploratorio de datos
#
# ### Separación de los datos en categoricos y numericos

# %%
numerical = df.select_dtypes(exclude=['object'])
categorical = df.select_dtypes(include=['object'])

# %%
numerical.head()
# Out:
#    periodo   id_cli  fecha_nacimiento     edad  ult_actual  categoria  \
# 0   202003  2089776          19840630 35.63860    20180526    1.00000
# 1   201902  2088089          19860727 32.47639    20181120    4.00000
# 2   202001  3892351          19910108 28.93634    20190802    4.00000
# 3   202008  2897552          19900903 29.88364    20190906    1.00000
# 4   202001  4782141          19790623 40.48186    20191211    1.00000
#
#    codigo_ciiu  mora_max  cant_moras_30_ult_12_meses  \
# 0           10       NaN                         NaN
# 1         8230       NaN                         NaN
# 2           10   0.00000                     0.00000
# 3           10   1.00000                     0.00000
# 4           10   0.00000                     0.00000
#
#    cant_moras_60_ult_12_meses  cant_moras_90_ult_12_meses  cupo_total_tc  \
# 0                         NaN                         NaN        0.00000
# 1                         NaN                         NaN        0.00000
# 2                     0.00000                     0.00000        0.00000
# 3                     0.00000                     0.00000        0.00000
# 4                     0.00000                     0.00000        0.00000
#
#    cuota_tc_bancolombia  nro_tot_cuentas  ctas_activas  ctas_embargadas  \
# 0               0.00000          1.00000       1.00000          0.00000
# 1               0.00000          1.00000       1.00000          0.00000
# 2               0.00000          1.00000       1.00000          0.00000
# 3               0.00000          1.00000       1.00000          0.00000
# 4               0.00000          1.00000       1.00000          0.00000
#
#    cuota_cred_hipot  mediana_nom3  mediana_pen3  ingreso_nompen  \
# 0               NaN 1255032.00000       0.00000   1255032.00000
# 1               NaN       0.00000       0.00000         0.00000
# 2               NaN       0.00000       0.00000         0.00000
# 3               NaN       0.00000       0.00000         0.00000
# 4               NaN 4353538.00000       0.00000   4353538.00000
#
#    ingreso_final  cant_mora_30_tdc_ult_3m_sf  cant_mora_30_consum_ult_3m_sf  \
# 0  1391032.00000                     0.00000                        0.00000
# 1  2327500.00000                         NaN                            NaN
# 2  6519750.00000                         NaN                            NaN
# 3  1484205.00000                     0.00000                        0.00000
# 4  4353334.00000                     0.00000                        0.00000
#
#    cuota_de_vivienda  cuota_de_consumo  cuota_rotativos  \
# 0            0.00000           0.00000          0.00000
# 1            0.00000           0.00000          0.00000
# 2            0.00000           0.00000          0.00000
# 3            0.00000           0.00000          0.00000
# 4            0.00000      386578.00000      11000.00000
#
#    cuota_tarjeta_de_credito  cuota_de_sector_solidario  \
# 0                   0.00000                    0.00000
# 1                   0.00000                    0.00000
# 2                   0.00000                    0.00000
# 3                   0.00000                    0.00000
# 4             1006000.00000                    0.00000
#
#    cuota_sector_real_comercio    cupo_tc_mdo  saldo_prom3_tdc_mdo  \
# 0                     0.00000        0.00000              0.00000
# 1                     0.00000        0.00000              0.00000
# 2                     0.00000        0.00000              0.00000
# 3                524000.00000        0.00000              0.00000
# 4                 28000.00000 25800000.00000       16242500.00000
#
#    cuota_tc_mdo  saldo_no_rot_mdo  cuota_libranza_sf  cant_oblig_tot_sf  \
# 0       0.00000           0.00000            0.00000            0.00000
# 1       0.00000           0.00000            0.00000                NaN
# 2       0.00000           0.00000            0.00000                NaN
# 3       0.00000     2555000.00000            0.00000            0.00000
# 4  751000.00000      211000.00000            0.00000            4.00000
#
#    cant_cast_ult_12m_sr           ind  pol_centr_ext  ingreso_nomina  \
# 0               0.00000  695516.00000        0.00000   1255032.00000
# 1                   NaN 1187025.00000            NaN             NaN
# 2                   NaN 3879251.25000            NaN             NaN
# 3               1.00000  210681.47500        7.00000             NaN
# 4               0.00000 1615755.80000        0.00000   4353538.00000
#
#    ingreso_segurida_social  gasto_familiar
# 0                      NaN    304687.00000
# 1                      NaN    187990.00000
# 2                      NaN    862348.92000
# 3            1484205.00000   1056864.00000
# 4            3500000.00000    248386.00000

# %%
categorical.head()
# Out:
#   genero estado_civil  nivel_academico            profesion      ocupacion  \
# 0      M   DIVORCIADO        TECNOLOGO  TECNOLOGIA SISTEMAS       Empleado
# 1      M  UNION LIBRE       NO INFORMA                   \N  Independiente
# 2      M      SOLTERO        TECNOLOGO                OTROS  Independiente
# 3      M      SOLTERO        BACHILLER                   \N       Empleado
# 4      F   NO INFORMA  SIN INFORMACION                   \N       Empleado
#
#   tipo_vivienda ind_mora_vigente cartera_castigada ciudad_residencia  \
# 0     ALQUILADA                N                 N              CALI
# 1      FAMILIAR                N                 N           PALMIRA
# 2            \N                N                 N          MEDELLIN
# 3            \N                N                 N          MEDELLIN
# 4            \N                N                 N       BOGOTA D.C.
#
#   departamento_residencia ciudad_laboral departamento_laboral rechazo_credito  \
# 0                   VALLE           CALI                VALLE              \N
# 1                   VALLE             \N                   \N              \N
# 2               ANTIOQUIA             \N                   \N              \N
# 3               ANTIOQUIA       MEDELLIN            ANTIOQUIA              \N
# 4            CUNDINAMARCA             \N                   \N              \N
#
#   tenencia_tc tiene_consumo tiene_crediagil tiene_ctas_activas  \
# 0          NO            \N              \N                  X
# 1          NO            \N              \N                  X
# 2          SI            \N              \N                  X
# 3          NO            \N              \N                  X
# 4          NO             X              \N                  X
#
#   tiene_ctas_embargadas pension_fopep tiene_cred_hipo_1 tiene_cred_hipo_2  \
# 0                    \N            \N                \N                \N
# 1                    \N            \N                \N                \N
# 2                    \N            \N                \N                \N
# 3                    \N            \N                \N                \N
# 4                    \N            \N                \N                \N
#
#   cat_ingreso rep_calif_cred convenio_lib
# 0         NOM              C           \N
# 1          \N       SIN INFO           \N
# 2          \N       SIN INFO           \N
# 3          \N              F           \N
# 4         NOM              C        70831

# %% [markdown]
# ### Variables categoricas

# %%
x = pd.DataFrame(categorical["genero"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["estado_civil"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["nivel_academico"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["ocupacion"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["tipo_vivienda"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["ind_mora_vigente"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["cartera_castigada"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["rechazo_credito"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["tenencia_tc"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["tiene_consumo"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["tiene_crediagil"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["tiene_ctas_activas"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["tiene_ctas_embargadas"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["pension_fopep"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["tiene_cred_hipo_1"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["tiene_cred_hipo_2"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["cat_ingreso"].value_counts())
x.plot.bar();

# %%
x = pd.DataFrame(categorical["rep_calif_cred"].value_counts())
x.plot.bar();

# %%
categorical["convenio_lib"].value_counts()
# Out:
# \N                   448653
# 70337                  5308
# REVISAR CONVENIOS      2860
# 75597                  1454
# 70238                  1177
#                       ...
# 72724                     1
# 74287                     1
# 79711                     1
# 20072                     1
# 70590                     1
# Name: convenio_lib, Length: 5328, dtype: int64

# %% [markdown]
# #### Variables a ser eliminadas por los siguientes motivos:
#
# - cartera_castigada - no aporta suficiente información, a la mayoria de las personas no se les ha castigado la cartera
# - rechazo_credito - no aporta suficiente información, a la mayoria no se les ha rechazado el credito
# - tiene_ctas_embargadas - no aporta suficiente información, casi no hay cuentas embargadas
# - pension_fopep - implicito en la var numerica, ya existe una variable que indica un valor por ingreso de pensión fopep
# - cat_ingreso - implicito en la variable numerica, ya existen varias variables que implican la categoria del ingreso
# - tiene_consumo - implicito en la variable numerica, ya existe una variable numerica que implicitamente indica si tiene credito de consumo
# - tiene_crediagil - implicito en la variable numerica, ya existe una variable numerico que indica si el cliente tiene credi agil
# - ocupación - tiene un sesgo demasiado alto hacia los trabajadores empleados y muy opoca información en general para el resto de sus categorias
# - tipo_vivienda - dificl hacer una consideración con tanto valor nulo
# - rep_calif_cred - no se tendrá en consideración por el momento

# %%
 categorical = categorical.drop(["departamento_residencia","departamento_laboral","ciudad_residencia","ciudad_laboral",
               "profesion", "cartera_castigada", "rechazo_credito", "tiene_ctas_embargadas",
               "pension_fopep", "cat_ingreso", "tipo_vivienda", "rep_calif_cred"], axis = 1)

# %% [markdown]
# #### Binarización de variables categoricas

# %%
def binarize_yes_no(x: str) -> int:
    if x == "S" or x == "SI" or x == "X": return 1
    return 0

def binarize_genre(x: str) -> int:
    if x == "M": return 1
    return 0

def binarize_mora(x: float) -> int:
    if x > 0: return 1
    return 0

def binarize_lib(x: str) -> int:
    if x == "\\N": return 0
    return 1

# %%
categorical["genero"] = categorical["genero"].apply(binarize_genre)
categorical["ind_mora_vigente"] = categorical["ind_mora_vigente"].apply(binarize_yes_no)
categorical["tenencia_tc"] = categorical["tenencia_tc"].apply(binarize_yes_no)
categorical["tiene_consumo"] = categorical["tiene_consumo"].apply(binarize_yes_no)
categorical["tiene_crediagil"] = categorical["tiene_crediagil"].apply(binarize_yes_no)
categorical["tiene_ctas_activas"] = categorical["tiene_ctas_activas"].apply(binarize_yes_no)
categorical["convenio_lib"] = categorical["convenio_lib"].apply(binarize_lib)
categorical["tiene_cred_hipo_1"] = categorical["tiene_cred_hipo_1"].apply(binarize_yes_no)
categorical["tiene_cred_hipo_2"] = categorical["tiene_cred_hipo_2"].apply(binarize_yes_no)

# %% [markdown]
# #### Transformación de variables categoricas
#
# Para el caso de las demas variables categoricas se realizará una simplificación mucho más fuerte de la siguiente manera:
#
# - estado_civil -> comparte_gastos (1 o 0), para los casos de casado y union libre, se considerará que la pareja comparte sus gastos.
# - nivel_academico -> Ingreso_profesional (1 o 0), en caso de tener perfil universitario o especialización, se considerara positivo para un ingreso profesional
# - ocupación -> contrato_def_indef (1 o 0), en caso de ser desempleado se considerará negativo para un ingreso propio
# - [tiene_consumo, tiene_crediagil, convenio_lib, tiene_cred_hipo_1, tiene_cred_hipo_1] -> credito activo (1 o 0), en caso de que algunas de las asociadas a creditos sea positivam, se considerara que el cliente tiene credito activo

# %%
def binarize_civil_status(x: str) -> int:
    if x == "CASADO" or x == "UNION LIBRE": return 1
    return 0

def binarize_academic_level(x: str) -> int:
    if x == "UNIVERSITARIO" or x == "ESPECIALIZACION" or x == "TECNOLOGO": return 1
    return 0

def binarize_occupation(x: str) -> int:
    if x == "Empleado": return 1
    return 0

def binarize_home(x: str) -> int:
    if x == "" or x == "": return 1
    return 0

# %%
categorical["comparte_gastos"] = categorical["estado_civil"].apply(binarize_civil_status)
categorical["ingreso_profesional"] = categorical["nivel_academico"].apply(binarize_academic_level)
categorical["contrato_def_indef"] = categorical["ocupacion"].apply(binarize_occupation)

# %%
categorical["credito_activo"] = categorical["ind_mora_vigente"] | categorical["convenio_lib"] \
                                | categorical["tiene_consumo"] | categorical["tiene_crediagil"] \
                                | categorical["tiene_cred_hipo_1"] | categorical["tiene_cred_hipo_2"]

# %%
categorical = categorical.drop(["estado_civil", "nivel_academico", "ocupacion",
                                "ind_mora_vigente", "convenio_lib", "tiene_consumo",
                                "tiene_crediagil", "tiene_cred_hipo_1", "tiene_cred_hipo_2"], 
                               axis = 1)

# %%
categorical.dtypes
# Out:
# genero                 int64
# tenencia_tc            int64
# tiene_ctas_activas     int64
# comparte_gastos        int64
# ingreso_profesional    int64
# contrato_def_indef     int64
# credito_activo         int64
# dtype: object

# %% [markdown]
# ### Variables numericas
#
# #### Imputación de valores nulos

# %%
numerical.isna().sum()
# Out:
# periodo                               0
# id_cli                                0
# fecha_nacimiento                      0
# edad                                111
# ult_actual                            0
# categoria                          5417
# codigo_ciiu                           0
# mora_max                         149564
# cant_moras_30_ult_12_meses       149564
# cant_moras_60_ult_12_meses       149564
# cant_moras_90_ult_12_meses       149564
# cupo_total_tc                         0
# cuota_tc_bancolombia                  0
# nro_tot_cuentas                      11
# ctas_activas                         11
# ctas_embargadas                      11
# cuota_cred_hipot                 483715
# mediana_nom3                          0
# mediana_pen3                          0
# ingreso_nompen                        0
# ingreso_final                      3826
# cant_mora_30_tdc_ult_3m_sf        81232
# cant_mora_30_consum_ult_3m_sf     81232
# cuota_de_vivienda                     0
# cuota_de_consumo                      0
# cuota_rotativos                       0
# cuota_tarjeta_de_credito              0
# cuota_de_sector_solidario             0
# cuota_sector_real_comercio            0
# cupo_tc_mdo                           0
# saldo_prom3_tdc_mdo                   0
# cuota_tc_mdo                          0
# saldo_no_rot_mdo                      0
# cuota_libranza_sf                     0
# cant_oblig_tot_sf                 84234
# cant_cast_ult_12m_sr              84234
# ind                                 165
# pol_centr_ext                     76419
# ingreso_nomina                   386421
# ingreso_segurida_social          378402
# gasto_familiar                        0
# dtype: int64

# %% [markdown]
# La edad y la categoria son variables que no deben imputarse, asi que se eliminaran los registros que contengan valores nulos, los demás se rellenaran con 0 dado que la naturaleza de su variable lo permite

# %%
numerical = numerical.dropna(subset = ["categoria", "edad"])
numerical = numerical.fillna(0)

# %% [markdown]
# #### Analisis de distribución

# %%
numerical["cuota_tc_bancolombia"].hist();

# %%
numerical["cuota_de_vivienda"].hist();

# %%
numerical["cuota_rotativos"].hist();

# %%
numerical["cuota_tc_mdo"].hist();

# %%
numerical["cuota_libranza_sf"].hist();

# %%
numerical["cuota_tarjeta_de_credito"].hist();

# %%
numerical["cuota_de_sector_solidario"].hist();

# %%
numerical["cuota_sector_real_comercio"].hist();

# %%
numerical["cuota_cred_hipot"].hist();

# %%
numerical["cuota_de_consumo"].hist();

# %% [markdown]
# Todas las cuotas presentan valores minimos en cero, no es que sean muy representativas estas graficas pero nos dan una idea sobre la magnitud de los datos, en este caso, podemos observar que para el credito de consumo existen valores negativos, por lo cual estos datos seran limpiados y convertidos en 0

# %%
numerical["cuota_de_consumo"] = np.where(numerical["cuota_de_consumo"] < 0, 0, numerical["cuota_de_consumo"])

# %%
numerical[["cuota_cred_hipot", "cuota_de_vivienda"]].head(30)
# Out:
#     cuota_cred_hipot  cuota_de_vivienda
# 0            0.00000            0.00000
# 1            0.00000            0.00000
# 2            0.00000            0.00000
# 3            0.00000            0.00000
# 4            0.00000            0.00000
# 5            0.00000            0.00000
# 6            0.00000            0.00000
# 7            0.00000            0.00000
# 8            0.00000            0.00000
# 9            0.00000            0.00000
# 10           0.00000            0.00000
# 11           0.00000            0.00000
# 12           0.00000            0.00000
# 13           0.00000       510000.00000
# 14           0.00000            0.00000
# 15           0.00000      1306000.00000
# 16           0.00000            0.00000
# 17           0.00000            0.00000
# 18           0.00000            0.00000
# 19           0.00000            0.00000
# 20           0.00000            0.00000
# 21           0.00000            0.00000
# 22           0.00000            0.00000
# 23           0.00000            0.00000
# 24           0.00000            0.00000
# 25           0.00000            0.00000
# 26           0.00000            0.00000
# 27           0.00000       429000.00000
# 28           0.00000            0.00000
# 29           0.00000            0.00000

# %%
f = numerical[numerical["cuota_cred_hipot"] != 0]
f[["cuota_cred_hipot", "cuota_de_vivienda"]].head(30)
# Out:
#      cuota_cred_hipot  cuota_de_vivienda
# 57      1290827.03000      1290827.03000
# 58      1294561.03000      1294561.03000
# 60      1084391.16000      1084391.16000
# 66       630691.38000       630691.38000
# 67       634447.38000       634447.38000
# 93       840767.05000       840767.05000
# 102     1630003.42000      1630003.42000
# 103     1619466.42000      1619466.42000
# 115      738411.27000       738411.27000
# 132      223726.64500       223726.64500
# 150      917105.14000       917105.14000
# 153     1857475.74000      1857475.74000
# 164      279900.63000       279900.63000
# 166      478325.71000       478325.71000
# 167      469422.71000       469422.71000
# 168      472885.71000       472885.71000
# 180      478858.24500       478858.24500
# 212      839384.88000       839384.88000
# 225      383090.37022       383090.37022
# 257      563893.38000       563893.38000
# 299      750365.45000       750365.45000
# 351      592405.04000       592405.04000
# 363      959887.95000       959887.95000
# 373     4346179.18000      4346179.18000
# 389     1529105.47000      1529105.47000
# 393      316645.11000       316645.11000
# 395      827202.29973       827202.29973
# 396      814446.97870       814446.97870
# 414      620491.84000       620491.84000
# 432      850298.03000      1251298.03000

# %% [markdown]
# De las tablas anteriores podemos observar que un credito hipotecario es a su vez un credito de vivienda, pero no en el sentido contrario, por lo tanto, se realizara una transformación sobre estas 2 variables, tomando el valor maximo entre las 2 columnas

# %%
numerical['cuota_cred_hipot'] = numerical[['cuota_cred_hipot', 'cuota_de_vivienda']].max(axis=1)

# %%
numerical["total_cuotas"] = numerical["cuota_tc_bancolombia"] + numerical["cuota_cred_hipot"] \
                            + numerical["cuota_de_consumo"] + numerical["cuota_rotativos"] \
                            + numerical["cuota_tarjeta_de_credito"] + numerical["cuota_de_sector_solidario"] \
                            + numerical["cuota_libranza_sf"] + numerical["cuota_tc_mdo"]

# %%
numerical = numerical.drop(["cuota_tc_bancolombia", "cuota_cred_hipot", "cuota_de_consumo",
                            "cuota_rotativos", "cuota_tarjeta_de_credito", "cuota_de_sector_solidario",
                            "cuota_libranza_sf", "cuota_tc_mdo", "cuota_de_vivienda",
                            "cuota_sector_real_comercio"], axis = 1)

# %%
numerical[["ingreso_nomina","ingreso_nompen"]].head()
# Out:
#    ingreso_nomina  ingreso_nompen
# 0   1255032.00000   1255032.00000
# 1         0.00000         0.00000
# 2         0.00000         0.00000
# 3         0.00000         0.00000
# 4   4353538.00000   4353538.00000

# %% [markdown]
# Para el caso de los ingresos de nomina y nompen, ocurre exactamente lo mismo que para el credito hipotecario y el credito de vivienda, asi que se hará una reducción similar ademas de sumarlo con el ingreso por seguridad social

# %%
numerical["ingreso_oc"] = numerical['ingreso_segurida_social']  +  \
                          numerical[['ingreso_nompen', 'ingreso_nomina']].max(axis=1)

# %%
numerical[["ingreso_oc","ingreso_final"]].head()
# Out:
#      ingreso_oc  ingreso_final
# 0 1255032.00000  1391032.00000
# 1       0.00000  2327500.00000
# 2       0.00000  6519750.00000
# 3 1484205.00000  1484205.00000
# 4 7853538.00000  4353334.00000

# %% [markdown]
# En la tabla anterior puede observarse que ocurre el mismo femoneno (nuevamente) de la cuota por credito hipotecario y de vivienda, asi que se dejara el valor mayor entre el ingreso por otros conceptos y el ingreso final

# %%
numerical["ingreso_corregido"] = numerical[['ingreso_final', 'ingreso_oc']].max(axis=1)

# %%
numerical = numerical.drop(["ingreso_segurida_social", "ingreso_oc", "ingreso_nomina",
                            "ingreso_nompen", "ingreso_final"], axis = 1)

# %%
numerical = numerical.drop(["id_cli", "fecha_nacimiento", "ult_actual", "codigo_ciiu"], axis = 1)

# %%
numerical["ind"].hist();

# %%
numerical["ind"] = np.where(numerical["ind"] < 0, 0, numerical["ind"])

# %%
numerical["ind"].hist();

# %%
plt.figure(figsize = (65,60))
corrMatrix = numerical.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# del diagrama de correlación anterior puede determinarse que se eliminaran las variables relacionadas con la mora, dado que presentan una correlación muy alta. Ademas, el ingreso corregido presenta una alta correlación con el ind, por lo tanto se opta por la eliminación del ingreso corregido

# %%
numerical = numerical.drop(["cant_moras_30_ult_12_meses", "cant_moras_60_ult_12_meses", "cant_moras_90_ult_12_meses", 
                            "ingreso_corregido"], axis = 1)

# %% [markdown]
# ## Limpieza del dataset

# %%
df["genero"] = df["genero"].apply(binarize_genre)
df["ind_mora_vigente"] = df["ind_mora_vigente"].apply(binarize_yes_no)
df["tenencia_tc"] = df["tenencia_tc"].apply(binarize_yes_no)
df["tiene_consumo"] = df["tiene_consumo"].apply(binarize_yes_no)
df["tiene_crediagil"] = df["tiene_crediagil"].apply(binarize_yes_no)
df["tiene_ctas_activas"] = df["tiene_ctas_activas"].apply(binarize_yes_no)
df["convenio_lib"] = df["convenio_lib"].apply(binarize_lib)
df["tiene_cred_hipo_1"] = df["tiene_cred_hipo_1"].apply(binarize_yes_no)
df["tiene_cred_hipo_2"] = df["tiene_cred_hipo_2"].apply(binarize_yes_no)

# %%
df["comparte_gastos"] = df["estado_civil"].apply(binarize_civil_status)
df["ingreso_profesional"] = df["nivel_academico"].apply(binarize_academic_level)
df["contrato_def_indef"] = df["ocupacion"].apply(binarize_occupation)

# %%
df["credito_activo"] = df["ind_mora_vigente"] | df["convenio_lib"] \
                        | df["tiene_consumo"] | df["tiene_crediagil"] \
                        | df["tiene_cred_hipo_1"] | df["tiene_cred_hipo_2"]

# %%
df = df.dropna(subset = ["categoria", "edad"])
df = df.fillna(0)

# %%
df["cuota_de_consumo"] = np.where(df["cuota_de_consumo"] < 0, 0, df["cuota_de_consumo"])

# %%
df['cuota_cred_hipot'] = df[['cuota_cred_hipot', 'cuota_de_vivienda']].max(axis=1)

# %%
df["total_cuotas"] = df["cuota_tc_bancolombia"] + df["cuota_cred_hipot"] \
                        + df["cuota_de_consumo"] + df["cuota_rotativos"] \
                        + df["cuota_tarjeta_de_credito"] + df["cuota_de_sector_solidario"] \
                        + df["cuota_libranza_sf"] + df["cuota_tc_mdo"]

# %%
df["ingreso_oc"] = df['ingreso_segurida_social']  +  \
                    df[['ingreso_nompen', 'ingreso_nomina']].max(axis=1)

# %%
df["ingreso_corregido"] = df[['ingreso_final', 'ingreso_oc']].max(axis=1)

# %%
df["ind"] = np.where(df["ind"] < 0, 0, df["ind"])

# %% [markdown]
# #### Eliminación de outliers

# %%
max_gf = df.gasto_familiar.quantile(0.95)
min_gf = df.gasto_familiar.quantile(0.05)
max_ind = df.ind.quantile(0.95)
min_ind = df.ind.quantile(0.05)

# %%
df = df[(df['ind'] > min_ind) & (df['ind']< max_ind)]
df = df[(df['gasto_familiar'] > min_gf) & (df['gasto_familiar']< max_gf)]

# %%
df = df.drop(["departamento_residencia","departamento_laboral","ciudad_residencia","ciudad_laboral",
               "profesion", "cartera_castigada", "rechazo_credito", "tiene_ctas_embargadas",
               "pension_fopep", "cat_ingreso", "tipo_vivienda", "rep_calif_cred",
               "estado_civil", "nivel_academico", "ocupacion",
               "ind_mora_vigente", "convenio_lib", "tiene_consumo",
               "tiene_crediagil", "tiene_cred_hipo_1", "tiene_cred_hipo_2",
               "cuota_tc_bancolombia", "cuota_cred_hipot", "cuota_de_consumo",
               "cuota_rotativos", "cuota_tarjeta_de_credito", "cuota_de_sector_solidario",
               "cuota_libranza_sf", "cuota_tc_mdo", "cuota_de_vivienda",
               "cuota_sector_real_comercio", "ingreso_segurida_social", "ingreso_oc", 
               "ingreso_nomina", "ingreso_nompen", "ingreso_final",
               "id_cli", "fecha_nacimiento", "ult_actual", "codigo_ciiu",
               "cant_moras_30_ult_12_meses", "cant_moras_60_ult_12_meses", 
               "cant_moras_90_ult_12_meses", "ingreso_corregido"
              ], axis = 1)

# %%
df.head()
# Out:
#    periodo     edad  genero  categoria  mora_max  cupo_total_tc  tenencia_tc  \
# 0   202003 35.63860       1    1.00000   0.00000        0.00000            0
# 1   201902 32.47639       1    4.00000   0.00000        0.00000            0
# 2   202001 28.93634       1    4.00000   0.00000        0.00000            1
# 3   202008 29.88364       1    1.00000   1.00000        0.00000            0
# 4   202001 40.48186       0    1.00000   0.00000        0.00000            0
#
#    nro_tot_cuentas  ctas_activas  tiene_ctas_activas  ctas_embargadas  \
# 0          1.00000       1.00000                   1          0.00000
# 1          1.00000       1.00000                   1          0.00000
# 2          1.00000       1.00000                   1          0.00000
# 3          1.00000       1.00000                   1          0.00000
# 4          1.00000       1.00000                   1          0.00000
#
#    mediana_nom3  mediana_pen3  cant_mora_30_tdc_ult_3m_sf  \
# 0 1255032.00000       0.00000                     0.00000
# 1       0.00000       0.00000                     0.00000
# 2       0.00000       0.00000                     0.00000
# 3       0.00000       0.00000                     0.00000
# 4 4353538.00000       0.00000                     0.00000
#
#    cant_mora_30_consum_ult_3m_sf    cupo_tc_mdo  saldo_prom3_tdc_mdo  \
# 0                        0.00000        0.00000              0.00000
# 1                        0.00000        0.00000              0.00000
# 2                        0.00000        0.00000              0.00000
# 3                        0.00000        0.00000              0.00000
# 4                        0.00000 25800000.00000       16242500.00000
#
#    saldo_no_rot_mdo  cant_oblig_tot_sf  cant_cast_ult_12m_sr           ind  \
# 0           0.00000            0.00000               0.00000  695516.00000
# 1           0.00000            0.00000               0.00000 1187025.00000
# 2           0.00000            0.00000               0.00000 3879251.25000
# 3     2555000.00000            0.00000               1.00000  210681.47500
# 4      211000.00000            4.00000               0.00000 1615755.80000
#
#    pol_centr_ext  gasto_familiar  comparte_gastos  ingreso_profesional  \
# 0        0.00000    304687.00000                0                    1
# 1        0.00000    187990.00000                1                    0
# 2        0.00000    862348.92000                0                    1
# 3        7.00000   1056864.00000                0                    0
# 4        0.00000    248386.00000                0                    0
#
#    contrato_def_indef  credito_activo  total_cuotas
# 0                   1               0       0.00000
# 1                   0               0       0.00000
# 2                   0               0       0.00000
# 3                   1               0       0.00000
# 4                   1               1 2154578.00000

# %%
plt.figure(figsize = (65,60))
corrMatrix = df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# Del diagrama de correlación anterior se eliminaran las variables de cupo_total_tc, tiene_ctas_activas y cant_oblig_tot_sf, por alta correlación con otras variables

# %%
df = df.drop(["cupo_total_tc", "tiene_ctas_activas", "cant_oblig_tot_sf", "periodo"], axis = 1)

# %%
X = df.drop(["gasto_familiar"], axis = 1)
Y = df["gasto_familiar"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNetCV

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,random_state=7)

# %%
ENReg = ElasticNetCV(random_state = 0)
ENReg.fit(X_train, y_train)
# Out:
# ElasticNetCV(random_state=0)

# %%
def mean_absolute_percentage_error(y_pred, y_true):
    y_true = np.where(y_true == 0, 0.0000000001, y_true)
    return np.mean(np.abs((y_true - y_pred) / y_true))

# %%
y_pred = ENReg.predict(X_test)

# %%
mape = mean_absolute_percentage_error2(y_pred, y_test)
mape
# Out:
# 77.3601438145303

# %%
from sklearn.ensemble import GradientBoostingRegressor

params = {'n_estimators': 500, 'max_depth': 6, 'verbose': 2,
          'loss': 'huber','alpha':0.95}

GBReg = GradientBoostingRegressor(**params).fit(X_train, y_train)
# Out:
#       Iter       Train Loss   Remaining Time
#          1 157431102781.6893            8.83m
#          2 153142775919.2596            8.86m
#          3 149581412006.6627            8.87m
#          4 146672816531.3174            8.88m
#          5 144305903021.7981            8.89m
#          6 142330854716.1695            8.88m
#          7 140693991372.4206            8.88m
#          8 139322549001.3343            8.87m
#          9 138167115220.7721            8.86m
#         10 137208416193.2222            8.84m
#         11 136393870108.4748            8.83m
#         12 135702078394.0191            8.81m
#         13 135119836935.3476            8.80m
#         14 134608854090.0948            8.78m
#         15 134161849404.5903            8.77m
#         16 133770272795.7695            8.75m
#         17 133448294346.6677            8.74m
#         18 133168267632.0603            8.71m
#         19 132893850253.2310            8.69m
#         20 132641110942.5196            8.67m
#         21 132431949636.4560            8.65m
#         22 132242487050.9993            8.63m
#         23 132064470587.0485            8.61m
#         24 131902428859.8344            8.58m
#         25 131755400521.5657            8.55m
#         26 131609003186.2496            8.53m
#         27 131484139767.7513            8.51m
#         28 131374922892.8022            8.48m
#         29 131249309907.8978            8.45m
#         30 131125073075.2979            8.42m
#         31 131037252326.0784            8.40m
#         32 130947504330.4912            8.37m
#         33 130862987925.8375            8.34m
#         34 130777982049.7079            8.32m
#         35 130694885263.3918            8.30m
#         36 130593239307.1421            8.28m
#         37 130537835191.6652            8.25m
#         38 130456849089.7618            8.23m
#         39 130379190974.6026            8.20m
#         40 130322676873.7872            8.18m
#         41 130277210705.2673            8.15m
#         42 130204244957.2229            8.13m
#         43 130120783272.5765            8.10m
#         44 130030095966.6583            8.08m
#         45 129978639019.5482            8.06m
#         46 129936550855.1174            8.03m
#         47 129896075450.4083            8.01m
#         48 129840136365.6685            7.99m
#         49 129786405181.6844            7.96m
#         50 129755341824.8063            7.94m
#         51 129690815329.3697            7.92m
#         52 129633646075.0088            7.90m
#         53 129583804269.3015            7.88m
#         54 129544677053.3640            7.86m
#         55 129513104362.4842            7.83m
#         56 129488730534.7680            7.81m
#         57 129441251619.2866            7.79m
#         58 129390797714.9162            7.77m
#         59 129304720802.1290            7.75m
#         60 129282049908.9894            7.73m
#         61 129253425560.6782            7.70m
#         62 129219489230.6868            7.68m
#         63 129180884338.1769            7.66m
#         64 129149322189.7600            7.64m
#         65 129110498468.8887            7.62m
#         66 129088166905.0664            7.60m
#         67 129031955728.3008            7.59m
#         68 129003824453.1280            7.56m
#         69 128979467206.5213            7.54m
#         70 128933314216.1496            7.52m
#         71 128884429678.7311            7.50m
#         72 128821628104.3486            7.48m
#         73 128773986118.2412            7.46m
#         74 128731327271.4826            7.44m
#         75 128717911962.1066            7.42m
#         76 128697138153.8701            7.40m
#         77 128672403258.6149            7.38m
#         78 128628686150.7915            7.36m
#         79 128600998514.3327            7.34m
#         80 128565787795.7691            7.32m
#         81 128503653711.8067            7.30m
#         82 128477388308.2893            7.28m
#         83 128455358268.4323            7.26m
#         84 128436965052.4267            7.24m
#         85 128425024981.2167            7.22m
#         86 128413736287.7431            7.20m
#         87 128393326722.2136            7.18m
#         88 128360958981.4627            7.16m
#         89 128334864619.6520            7.14m
#         90 128303610466.5090            7.12m
#         91 128269966097.7632            7.10m
#         92 128230586707.8061            7.08m
#         93 128203215746.5113            7.06m
#         94 128181899849.1382            7.04m
#         95 128147288519.0095            7.02m
#         96 128117687806.8741            7.01m
#         97 128068353335.2285            6.99m
#         98 128046958715.9203            6.97m
#         99 127997405719.0451            6.95m
#        100 127983358124.4653            6.93m
#        101 127957581212.1469            6.91m
#        102 127946416561.8607            6.89m
#        103 127936837009.9712            6.87m
#        104 127901925854.6278            6.85m
#        105 127870196000.4062            6.83m
#        106 127817690660.8727            6.82m
#        107 127781643165.5283            6.80m
#        108 127740955811.0106            6.78m
#        109 127723966539.3719            6.76m
#        110 127695071733.6714            6.74m
#        111 127657299284.4875            6.72m
#        112 127632278016.3898            6.70m
#        113 127599022393.7768            6.68m
#        114 127571957098.4926            6.66m
#        115 127552426704.1889            6.65m
#        116 127535603935.4498            6.63m
#        117 127494228817.5036            6.61m
#        118 127478988663.2811            6.59m
#        119 127434608232.2225            6.57m
#        120 127414454056.6497            6.55m
#        121 127405659665.0655            6.53m
#        122 127375880610.8015            6.51m
#        123 127329168918.0069            6.50m
#        124 127319458519.0561            6.48m
#        125 127270255716.0275            6.46m
#        126 127246717281.3772            6.44m
#        127 127200852686.6982            6.42m
#        128 127153158899.0783            6.40m
#        129 127129663900.0547            6.39m
#        130 127104734324.0167            6.37m
#        131 127071444406.4182            6.35m
#        132 127047882284.5073            6.33m
#        133 127028667577.2849            6.31m
#        134 127005670057.4881            6.30m
#        135 126982245010.5832            6.28m
#        136 126959263160.2603            6.26m
#        137 126935316393.6809            6.24m
#        138 126908827352.6329            6.22m
#        139 126873671908.0112            6.20m
#        140 126841832115.9358            6.19m
#        141 126827874769.3145            6.17m
#        142 126814695582.8950            6.15m
#        143 126797051582.2260            6.13m
#        144 126762097313.7249            6.11m
#        145 126731232595.0244            6.10m
#        146 126695401484.6623            6.08m
#        147 126669688286.6754            6.06m
#        148 126633344960.6595            6.04m
#        149 126604666224.7194            6.02m
#        150 126575000067.7130            6.01m
#        151 126555010988.6454            5.99m
#        152 126551042764.1385            5.97m
#        153 126522408560.3551            5.95m
#        154 126504344834.0871            5.93m
#        155 126479997291.5368            5.91m
#        156 126451494531.8754            5.90m
#        157 126425108689.7824            5.88m
#        158 126394654855.3770            5.86m
#        159 126373330780.8304            5.84m
#        160 126354754706.6082            5.82m
#        161 126321006500.8977            5.81m
#        162 126304092529.9644            5.79m
#        163 126279285465.7024            5.77m
#        164 126257459686.6378            5.76m
#        165 126232689029.1370            5.74m
#        166 126203425168.4495            5.72m
#        167 126177055828.4445            5.70m
#        168 126147756164.3875            5.68m
#        169 126117160398.4670            5.67m
#        170 126090332723.0918            5.65m
#        171 126065371628.6518            5.63m
#        172 126042073682.0762            5.61m
#        173 126008877908.2078            5.59m
#        174 125993739003.3624            5.58m
#        175 125962300405.1346            5.56m
#        176 125927737457.7531            5.54m
#        177 125909118507.5233            5.52m
#        178 125879640750.7778            5.51m
#        179 125851581520.6616            5.49m
#        180 125836939263.4337            5.47m
#        181 125828678529.7659            5.45m
#        182 125809875777.4183            5.43m
#        183 125772749800.1112            5.42m
#        184 125750687961.5679            5.40m
#        185 125744691239.3613            5.38m
#        186 125716300643.9442            5.36m
#        187 125694040870.0141            5.35m
#        188 125674209078.7591            5.33m
#        189 125665179613.0027            5.31m
#        190 125637046633.5861            5.29m
#        191 125623407755.1637            5.28m
#        192 125614749924.6842            5.26m
#        193 125603748132.1937            5.24m
#        194 125587188478.7606            5.22m
#        195 125563237930.5041            5.20m
#        196 125521675641.0381            5.19m
#        197 125511951364.1431            5.17m
#        198 125489403884.6679            5.15m
#        199 125475683302.5860            5.13m
#        200 125452091849.1595            5.12m
#        201 125424293304.7022            5.10m
#        202 125411444279.2636            5.08m
#        203 125386475658.6499            5.07m
#        204 125373776111.3728            5.05m
#        205 125368157135.5321            5.03m
#        206 125344375330.4936            5.01m
#        207 125321725479.1678            5.00m
#        208 125300039100.1703            4.98m
#        209 125283709742.1861            4.96m
#        210 125255740797.0747            4.94m
#        211 125226762193.9359            4.93m
#        212 125208536443.7504            4.91m
#        213 125184278981.1997            4.89m
#        214 125168245611.9967            4.87m
#        215 125147100204.9383            4.86m
#        216 125126442461.9511            4.84m
#        217 125112183035.1516            4.82m
#        218 125096129101.8821            4.80m
#        219 125076341440.4966            4.79m
#        220 125057909889.4823            4.77m
#        221 125039517699.6979            4.75m
#        222 125022226663.4793            4.74m
#        223 125010559520.8351            4.72m
#        224 124994828766.2719            4.70m
#        225 124976181617.4755            4.68m
#        226 124969336092.1948            4.67m
#        227 124947946623.9391            4.65m
#        228 124942337553.1358            4.63m
#        229 124920220180.7457            4.61m
#        230 124888859929.2581            4.60m
#        231 124872757551.8663            4.58m
#        232 124863896040.9286            4.56m
#        233 124849658365.7818            4.54m
#        234 124830911192.0598            4.53m
#        235 124808278056.6589            4.51m
#        236 124781645693.0529            4.49m
#        237 124760108421.7256            4.48m
#        238 124741968099.7228            4.46m
#        239 124724273269.3645            4.44m
#        240 124709605891.6269            4.42m
#        241 124695380203.2308            4.41m
#        242 124682589891.4160            4.39m
#        243 124660738843.4492            4.37m
#        244 124618353138.3912            4.35m
#        245 124601190253.0066            4.34m
#        246 124581589889.0198            4.32m
#        247 124559914039.1856            4.30m
#        248 124542524196.3075            4.28m
#        249 124524609644.4700            4.27m
#        250 124513077881.1746            4.25m
#        251 124484468899.1795            4.23m
#        252 124454228855.1049            4.22m
#        253 124430722334.1953            4.20m
#        254 124397307779.4491            4.18m
#        255 124366899874.6621            4.16m
#        256 124350586550.1000            4.15m
#        257 124318704093.8895            4.13m
#        258 124288858987.9701            4.11m
#        259 124254612204.0696            4.10m
#        260 124218290045.5385            4.08m
#        261 124193051772.1182            4.06m
#        262 124175658089.2511            4.04m
#        263 124152881507.1843            4.03m
#        264 124129286567.3642            4.01m
#        265 124105607356.8779            3.99m
#        266 124088419963.1287            3.98m
#        267 124070214177.8466            3.96m
#        268 124050111154.3492            3.94m
#        269 124035818787.6807            3.92m
#        270 124014234469.7931            3.91m
#        271 123983851445.1521            3.89m
#        272 123952475369.6373            3.87m
#        273 123937825709.0965            3.85m
#        274 123924741405.6455            3.84m
#        275 123902449362.8369            3.82m
#        276 123871979984.8369            3.80m
#        277 123853832596.5329            3.78m
#        278 123839520585.0648            3.77m
#        279 123822117071.2997            3.75m
#        280 123809731881.0470            3.73m
#        281 123797064611.3405            3.71m
#        282 123771027614.2224            3.70m
#        283 123751149686.5722            3.68m
#        284 123727212987.3428            3.66m
#        285 123701785924.8280            3.64m
#        286 123677306957.4994            3.63m
#        287 123658204573.9489            3.61m
#        288 123636778052.6667            3.59m
#        289 123619360273.9101            3.57m
#        290 123608021320.0848            3.56m
#        291 123579006806.4950            3.54m
#        292 123563003455.7430            3.52m
#        293 123547652918.4396            3.50m
#        294 123528500294.8092            3.49m
#        295 123504922991.5219            3.47m
#        296 123493229930.8259            3.45m
#        297 123481355434.7938            3.43m
#        298 123450387524.9822            3.42m
#        299 123417409694.3168            3.40m
#        300 123396761503.1231            3.38m
#        301 123366966562.2084            3.36m
#        302 123340857633.6275            3.35m
#        303 123315879860.9994            3.33m
#        304 123293082622.3978            3.31m
#        305 123276656396.0256            3.29m
#        306 123256208108.5773            3.28m
#        307 123231685024.4045            3.26m
#        308 123205858634.4353            3.24m
#        309 123176459800.0379            3.22m
#        310 123152099201.1455            3.21m
#        311 123133052583.9581            3.19m
#        312 123112920002.6797            3.17m
#        313 123090023313.1943            3.16m
#        314 123066231121.2210            3.14m
#        315 123035808433.6748            3.12m
#        316 123007077655.3798            3.10m
#        317 122981854282.2056            3.09m
#        318 122963644316.9277            3.07m
#        319 122944238722.5357            3.05m
#        320 122925896981.5772            3.03m
#        321 122916598003.9908            3.02m
#        322 122903001386.8308            3.00m
#        323 122884181606.1492            2.98m
#        324 122864202108.5471            2.96m
#        325 122847771084.8473            2.95m
#        326 122833593663.2614            2.93m
#        327 122826933385.0333            2.91m
#        328 122808228199.0308            2.90m
#        329 122788769531.7439            2.88m
#        330 122771975496.4148            2.86m
#        331 122757769740.7213            2.84m
#        332 122736755556.2960            2.83m
#        333 122705183261.1162            2.81m
#        334 122679232677.8263            2.79m
#        335 122667925115.9802            2.77m
#        336 122650253395.4239            2.76m
#        337 122628917277.5943            2.74m
#        338 122610237242.4127            2.72m
#        339 122604126666.0322            2.71m
#        340 122594884515.6668            2.69m
#        341 122580968647.9864            2.67m
#        342 122544290725.0109            2.65m
#        343 122523213965.8926            2.64m
#        344 122508101686.5291            2.62m
#        345 122492833811.9783            2.60m
#        346 122480837497.3029            2.59m
#        347 122464666411.6752            2.57m
#        348 122449646704.4742            2.55m
#        349 122429499961.8529            2.53m
#        350 122414528192.3259            2.52m
#        351 122406324314.2397            2.50m
#        352 122382672338.5902            2.48m
#        353 122371184419.1761            2.47m
#        354 122355535832.9029            2.45m
#        355 122325721420.1584            2.43m
#        356 122306917878.1711            2.41m
#        357 122288211571.2291            2.40m
#        358 122278502718.4852            2.38m
#        359 122261386824.4877            2.36m
#        360 122244151483.3784            2.35m
#        361 122223082216.5733            2.33m
#        362 122214377837.2141            2.31m
#        363 122207627759.4676            2.30m
#        364 122191762409.3953            2.28m
#        365 122175827760.6494            2.26m
#        366 122157779566.1788            2.24m
#        367 122139421210.8403            2.23m
#        368 122121310915.5763            2.21m
#        369 122103206602.4976            2.19m
#        370 122079900212.3179            2.18m
#        371 122061239033.8220            2.16m
#        372 122049477292.2010            2.14m
#        373 122035247635.9416            2.13m
#        374 122018004142.3119            2.11m
#        375 122010737193.0003            2.09m
#        376 121999563895.7285            2.08m
#        377 121987709605.3792            2.06m
#        378 121971311183.4002            2.04m
#        379 121956259171.7504            2.02m
#        380 121943788866.2884            2.01m
#        381 121927621612.1107            1.99m
#        382 121919276306.5178            1.97m
#        383 121907687215.5705            1.96m
#        384 121899051801.3102            1.94m
#        385 121884673134.8597            1.92m
#        386 121873824750.1106            1.91m
#        387 121862669198.0768            1.89m
#        388 121853774277.6529            1.87m
#        389 121837000083.0750            1.86m
#        390 121807572431.8468            1.84m
#        391 121791360004.2587            1.82m
#        392 121772255556.9115            1.80m
#        393 121749524574.1888            1.79m
#        394 121720952113.8246            1.77m
#        395 121699799768.8898            1.75m
#        396 121688534416.8258            1.74m
#        397 121672030419.0075            1.72m
#        398 121656920993.2899            1.70m
#        399 121634444327.8285            1.69m
#        400 121622143515.6979            1.67m
#        401 121610722722.5012            1.65m
#        402 121599212377.1809            1.64m
#        403 121588933797.0716            1.62m
#        404 121580890868.2747            1.60m
#        405 121575241047.5862            1.59m
#        406 121567771343.0339            1.57m
#        407 121555169826.1865            1.55m
#        408 121540937639.7621            1.54m
#        409 121524235700.2151            1.52m
#        410 121516650955.9245            1.50m
#        411 121502662628.5462            1.49m
#        412 121490446917.3058            1.47m
#        413 121475535702.5447            1.45m
#        414 121461368837.4863            1.44m
#        415 121448032600.1315            1.42m
#        416 121424327978.1699            1.40m
#        417 121410231768.5713            1.38m
#        418 121394647899.0836            1.37m
#        419 121379490822.8163            1.35m
#        420 121368671267.9014            1.33m
#        421 121360462918.3773            1.32m
#        422 121351702200.1746            1.30m
#        423 121332191703.9800            1.28m
#        424 121309065408.0451            1.27m
#        425 121293166177.7594            1.25m
#        426 121272547727.6911            1.23m
#        427 121256619593.1932            1.22m
#        428 121239778194.7586            1.20m
#        429 121227490897.5407            1.18m
#        430 121216979611.5518            1.17m
#        431 121204614549.6270            1.15m
#        432 121189237904.7633            1.13m
#        433 121170808444.1731            1.12m
#        434 121147977865.4021            1.10m
#        435 121131308977.1841            1.08m
#        436 121115953190.4896            1.07m
#        437 121101249218.0596            1.05m
#        438 121087842098.5184            1.03m
#        439 121071295798.4909            1.02m
#        440 121062216032.9267           59.97s
#        441 121052181560.6419           58.96s
#        442 121043647755.4501           57.96s
#        443 121034995941.8480           56.96s
#        444 121022053130.9369           55.96s
#        445 121004947748.8906           54.95s
#        446 120996182380.7568           53.95s
#        447 120988607692.9045           52.95s
#        448 120974721140.1235           51.95s
#        449 120965514662.2385           50.95s
#        450 120958052748.4886           49.94s
#        451 120952162772.3100           48.94s
#        452 120944595291.6128           47.94s
#        453 120936047264.7202           46.94s
#        454 120927167538.9906           45.94s
#        455 120918426108.0980           44.93s
#        456 120904616878.8922           43.93s
#        457 120890000353.8377           42.93s
#        458 120881534512.3047           41.93s
#        459 120870119546.6996           40.93s
#        460 120850587238.8203           39.93s
#        461 120820778148.3372           38.93s
#        462 120810516236.2194           37.93s
#        463 120797408429.9137           36.93s
#        464 120776572572.3713           35.93s
#        465 120758696619.8819           34.93s
#        466 120747196771.3016           33.93s
#        467 120738916211.5188           32.93s
#        468 120728080763.3769           31.93s
#        469 120718759481.3021           30.93s
#        470 120711893931.2009           29.93s
#        471 120700707087.6334           28.93s
#        472 120692309146.4349           27.93s
#        473 120683888841.4918           26.93s
#        474 120674289301.7139           25.93s
#        475 120660485980.6880           24.93s
#        476 120648327261.4482           23.94s
#        477 120638541966.5019           22.94s
#        478 120624080766.5907           21.94s
#        479 120619292849.9096           20.94s
#        480 120611175158.9017           19.94s
#        481 120597265899.7193           18.94s
#        482 120591027777.1909           17.95s
#        483 120583405840.3468           16.95s
#        484 120574722662.9871           15.95s
#        485 120564318061.3415           14.95s
#        486 120551211793.0609           13.96s
#        487 120544482889.4959           12.96s
#        488 120534832371.5272           11.96s
#        489 120516751174.0054           10.96s
#        490 120505264447.5372            9.97s
#        491 120499726345.6452            8.97s
#        492 120495080643.8111            7.97s
#        493 120486343619.2355            6.98s
#        494 120472332894.7927            5.98s
#        495 120455860936.3546            4.98s
#        496 120449423403.2589            3.99s
#        497 120435058901.1439            2.99s
#        498 120414189035.0629            1.99s
#        499 120405862228.3773            1.00s
#        500 120392291477.7710            0.00s

# %%
y_pred = GBReg.predict(X_test)

# %%
mape = mean_absolute_percentage_error(y_pred, y_test)*100
mape
# Out:
# 8418.205434138285

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

regr = make_pipeline(StandardScaler(), ElasticNetCV(random_state = 0))
regr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('elasticnetcv', ElasticNetCV(random_state=0))])

# %%
y_pred = regr.predict(X_test)
mape = mean_absolute_percentage_error(y_pred, y_test)
mape
# Out:
# 65.13632296618107

# %%
sv = make_pipeline(StandardScaler(), SVR(C=1.0, epsilon=0.2, verbose=True))
sv.fit(X_train, y_train)
# Out:
# [LibSVM]..............................

# %%
y_pred = sv.predict(X_test)
mape = mean_absolute_percentage_error(y_pred, y_test)
mape
